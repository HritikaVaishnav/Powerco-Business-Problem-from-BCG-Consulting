# %% [markdown]
# ## Task 2: Exploratory Data Analysis

# %% [markdown]
# ### Import all required labraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# Shows plots in jupyter notebook
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Set plot style
sns.set(color_codes=True)

import matplotlib.ticker as ticker

# %% [markdown]
# ### Load and Read the Datasets

# %%
client_df = pd.read_csv("client_data (1).csv")
price_df = pd.read_csv("price_data (1).csv")

# %% [markdown]
# ### Visual Inspection of Dataset

# %%
client_df.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
client_df.tail()
# Out:
#                                      id                     channel_sales  \
# 14601  18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua
# 14602  d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua
# 14603  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14605  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 14601     32270         47940                0  2012-05-24  2016-05-08
# 14602      7223             0              181  2012-08-27  2016-08-27
# 14603      1844             0              179  2012-02-08  2016-02-07
# 14604       131             0                0  2012-08-30  2016-08-30
# 14605      8730             0                0  2009-12-18  2016-12-17
#
#       date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
client_df.shape
# Out:
# (14606, 26)

# %%
client_df.size
# Out:
# 379756

# %%
price_df.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
price_df.tail()
# Out:
#                                       id  price_date  price_off_peak_var  \
# 192997  16f51cdc2baa19af0b940ee1b3dd17d5  2015-08-01            0.119916
# 192998  16f51cdc2baa19af0b940ee1b3dd17d5  2015-09-01            0.119916
# 192999  16f51cdc2baa19af0b940ee1b3dd17d5  2015-10-01            0.119916
# 193000  16f51cdc2baa19af0b940ee1b3dd17d5  2015-11-01            0.119916
# 193001  16f51cdc2baa19af0b940ee1b3dd17d5  2015-12-01            0.119916
#
#         price_peak_var  price_mid_peak_var  price_off_peak_fix  \
# 192997        0.102232            0.076257           40.728885
# 192998        0.102232            0.076257           40.728885
# 192999        0.102232            0.076257           40.728885
# 193000        0.102232            0.076257           40.728885
# 193001        0.102232            0.076257           40.728885
#
#         price_peak_fix  price_mid_peak_fix
# 192997        24.43733           16.291555
# 192998        24.43733           16.291555
# ...

# %%
price_df.shape
# Out:
# (193002, 8)

# %%
price_df.size
# Out:
# 1544016

# %% [markdown]
# ### Descriptive statistics of data
# #### 1. Data types

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %% [markdown]
# **Insights:**
# 1. client_df dataset has float64(11), int64(7), and object(8).
# 2. client_df dataset has 14606 rows and 26 columns.
# 3. client_df dataset has `date_activ, date_end, date_modif_prod, and date_renewal` columns in the object type, so we will convert them into the date type.

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# **Insights:**
# 1. price_df dataset has float64(6) and object(2).
# 2. price_df dataset has 193002 rows and 8 columns.
# 3. price_df dataset has `price_date` column in the object type, so we will convert it into the date type.

# %% [markdown]
# #### 2. Statistics

# %%
client_df.describe().T
# Out:
#                                   count           mean            std  min  \
# cons_12m                        14606.0  159220.286252  573465.264198  0.0
# cons_gas_12m                    14606.0   28092.375325  162973.059057  0.0
# cons_last_month                 14606.0   16090.269752   64364.196422  0.0
# forecast_cons_12m               14606.0    1868.614880    2387.571531  0.0
# forecast_cons_year              14606.0    1399.762906    3247.786255  0.0
# forecast_discount_energy        14606.0       0.966726       5.108289  0.0
# forecast_meter_rent_12m         14606.0      63.086871      66.165783  0.0
# forecast_price_energy_off_peak  14606.0       0.137283       0.024623  0.0
# forecast_price_energy_peak      14606.0       0.050491       0.049037  0.0
# forecast_price_pow_off_peak     14606.0      43.130056       4.485988  0.0
# imp_cons                        14606.0     152.786896     341.369366  0.0
# ...

# %% [markdown]
# **Insights**
# * There is a significant variation in electricity consumption among clients. While the average consumption is around 159,220 kWh, some clients consume up to 6.2 million kWh, indicating the presence of both small and large consumers.
# * Most clients do not consume gas, as indicated by the median of 0 kWh. The large standard deviation and maximum value suggest that a few clients have very high gas consumption.
# * The electricity consumption in the last month shows a wide range. The median is much lower than the mean, indicating that most clients have relatively low consumption, but a few have extremely high usage.
# * The forecasted consumption for the next year is significantly lower than the actual past consumption, suggesting an expectation of reduced electricity usage.
# * The average discount is low, with many clients not receiving any discount. The meter rent is a moderate cost for the clients.
# * Off-peak energy prices are higher than peak energy prices, which is unusual and might warrant further investigation. The off-peak power price is substantial.
# * The current paid consumption varies greatly among clients, with a majority having low usage but some having very high usage.
# * Gross and net margins are nearly identical, suggesting minimal operating costs or other expenses.
# * Most clients have only one active product or service, with very few having multiple.
# * There is considerable variation in the net margin per client, with some clients contributing significantly more to the net margin than others.
# *  Clients have been with the company for an average of 5 years, suggesting a stable customer base.
# * The subscribed power varies, with most clients subscribing to around 14 kW, but some subscribing to much higher power levels.
# * Approximately 9.7% of clients have churned in the next 3 months, indicating a relatively low churn rate but with some variability across the client base.
#
# **Conculsion**
# * Consumption Patterns: There is a wide range of electricity and gas consumption among clients, with some exhibiting very high usage.
# * Forecasts vs. Actuals: Forecasted consumption is lower than past consumption, suggesting expectations of reduced usage.
# * Pricing Anomalies: Off-peak energy prices are higher than peak energy prices, which is unusual.
# * Client Loyalty: Clients have a stable relationship with the company, with an average tenure of 5 years.
# * Churn: The churn rate is low, indicating customer satisfaction and loyalty.

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# **Insights**
# * The average off-peak variable price is around €0.141 per kWh. Most clients are charged between €0.126 and €0.152 per kWh. There are some instances where the price is zero.
# *  The average peak variable price is €0.055 per kWh, with most clients paying between €0.000 and €0.102 per kWh. There are significant variations, with many clients not being charged during peak times.
# * The mid-peak variable price is generally low, with a mean of €0.030 per kWh. Many clients are not charged during mid-peak periods, as indicated by the median of zero.
# * The average off-peak fixed price is €43.33, with most clients being charged between €40.73 and €44.44. The prices are relatively consistent, but some clients have no off-peak fixed price.
# * The average peak fixed price is €10.62, with a large variation. Many clients are not charged a peak fixed price, as shown by the median of zero.
# * The mid-peak fixed price is generally low, with an average of €6.41. Similar to peak fixed prices, many clients are not charged a mid-peak fixed price.
#
# **Conculsion**
# * Variable Prices: Off-peak variable prices are higher on average than peak and mid-peak prices. Peak and mid-peak variable prices have a significant number of zero values, indicating that some clients are not charged during these times.
# * Fixed Prices: Off-peak fixed prices are relatively stable and higher than peak and mid-peak fixed prices. Many clients do not have any fixed prices for peak and mid-peak periods.
# * Pricing Anomalies: The presence of zero values for variable and fixed prices during peak and mid-peak periods suggests some clients have special pricing arrangements or exemptions.

# %% [markdown]
# ### Understanding of attributes

# %%
client_df.isnull().sum()
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# ...

# %%
price_df.isnull().sum()
# Out:
# id                    0
# price_date            0
# price_off_peak_var    0
# price_peak_var        0
# price_mid_peak_var    0
# price_off_peak_fix    0
# price_peak_fix        0
# price_mid_peak_fix    0
# dtype: int64

# %% [markdown]
# * client_df and price_df do not have null values.

# %%
client_df.duplicated().sum()
# Out:
# 0

# %%
price_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * client_df and price_df do not have Duplicated values.

# %% [markdown]
# ### Data visualization
# * Now let's dive a bit deeper into the dataframes

# %% [markdown]
# ### EDA For Client Dataset

# %%
# Plot histograms for numerical variables
numerical_columns = client_df.select_dtypes(include=['int64', 'float64']).columns
client_df[numerical_columns].hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

# %% [markdown]
# ### 1. Churn

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100

# %%
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %% [markdown]
# * About 10% of the total customers have churned.

# %% [markdown]
# ### 2. Sales channel

# %%
channel = client_df[['id', 'channel_sales', 'churn']]
channel = channel.groupby([channel['channel_sales'], channel['churn']])['id'].count().unstack(level=1).fillna(0)
channel_churn = (channel.div(channel.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(channel_churn, 'Sales channel', rot_=30)

# %% [markdown]
# Interestingly, the churning customers are distributed over 5 different values for `channel_sales`. As well as this, the value of `MISSING` has a churn rate of 7.6%. `MISSING` indicates a missing value and was added by the team when they were cleaning the dataset. This feature could be an important feature when it comes to building our model.
#
# ### 3. Consumption
#
# Let's see the distribution of the consumption in the last year and month. Since the consumption data is univariate, let's use histograms to visualize their distribution.

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

# %%
def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distribution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
fig, axs = plt.subplots(nrows=4, figsize=(18, 25))

plot_distribution(consumption, 'cons_12m', axs[0])
plot_distribution(consumption[consumption['has_gas'] == 't'], 'cons_gas_12m', axs[1])
plot_distribution(consumption, 'cons_last_month', axs[2])
plot_distribution(consumption, 'imp_cons', axs[3])

# %% [markdown]
# Clearly, the consumption data is highly positively skewed, presenting a very long right-tail towards the higher values of the distribution. The values on the higher and lower end of the distribution are likely to be outliers. We can use a standard plot to visualise the outliers in more detail. A boxplot is a standardized way of displaying the distribution based on a five number summary:
# - Minimum
# - First quartile (Q1)
# - Median
# - Third quartile (Q3)
# - Maximum
#
# It can reveal outliers and what their values are. It can also tell us if our data is symmetrical, how tightly our data is grouped and if/how our data is skewed.

# %%
fig, axs = plt.subplots(nrows=4, figsize=(20,25))
sns.boxplot(consumption['cons_12m'], ax=axs[0])
sns.boxplot(consumption[consumption['has_gas'] == 't']['cons_gas_12m'], ax=axs[1])
sns.boxplot(consumption['cons_last_month'], ax=axs[2])
sns.boxplot(consumption['imp_cons'], ax=axs[3])
# Out:
# <Axes: >

# %% [markdown]
# * We will deal with skewness and outliers during feature engineering in the next exercise.

# %% [markdown]
# ### 4. Forecast

# %%
forecast = client_df[
    ["id", "forecast_cons_12m",
    "forecast_cons_year","forecast_discount_energy","forecast_meter_rent_12m",
    "forecast_price_energy_off_peak","forecast_price_energy_peak",
    "forecast_price_pow_off_peak","churn"
    ]
]

# %%
fig, axs = plt.subplots(nrows=7, figsize=(18,50))

# Plot histogram
plot_distribution(client_df, "forecast_cons_12m", axs[0])
plot_distribution(client_df, "forecast_cons_year", axs[1])
plot_distribution(client_df, "forecast_discount_energy", axs[2])
plot_distribution(client_df, "forecast_meter_rent_12m", axs[3])
plot_distribution(client_df, "forecast_price_energy_off_peak", axs[4])
plot_distribution(client_df, "forecast_price_energy_peak", axs[5])
plot_distribution(client_df, "forecast_price_pow_off_peak", axs[6])

# %% [markdown]
# * Similarly to the consumption plots, we can observe that a lot of the variables are highly positively skewed, creating a very long tail for the higher values. We will make some transformations during the next exercise to correct for this skewness.

# %% [markdown]
# ### 5. Contract type

# %%
contract_type = client_df[['id', 'has_gas', 'churn']]
contract = contract_type.groupby([contract_type['churn'], contract_type['has_gas']])['id'].count().unstack(level=0)
contract_percentage = (contract.div(contract.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(contract_percentage, 'Contract type (with gas')

# %% [markdown]
# ### 6. Margins

# %%
margin = client_df[['id', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'net_margin']]

# %%
fig, axs = plt.subplots(nrows=3, figsize=(18,20))
# Plot histogram
sns.boxplot(margin["margin_gross_pow_ele"], ax=axs[0])
sns.boxplot(margin["margin_net_pow_ele"],ax=axs[1])
sns.boxplot(margin["net_margin"], ax=axs[2])
plt.show()

# %% [markdown]
# * We can see some outliers here as well which we will deal with in the next exercise.

# %% [markdown]
# ### 7. Subscribed power

# %%
power = client_df[['id', 'pow_max', 'churn']]

# %%
fig, axs = plt.subplots(nrows=1, figsize=(18, 10))
plot_distribution(power, 'pow_max', axs)

# %% [markdown]
# ### 8. Date_features

# %%
date_features = client_df[['id', 'date_activ', 'date_end', 'date_modif_prod', 'date_renewal', 'churn']].copy()

# %%
date_features['date_activ'] = pd.to_datetime(date_features['date_activ'], format='%Y-%m-%d')
date_features['date_end'] = pd.to_datetime(date_features['date_end'], format='%Y-%m-%d')
date_features['date_modif_prod'] = pd.to_datetime(date_features['date_modif_prod'], format='%Y-%m-%d')
date_features['date_renewal'] = pd.to_datetime(date_features['date_renewal'], format='%Y-%m-%d')

# %%
def plot_dates(dataframe, column, fontsize_=12):
    """
    Plot monthly churn and retention distribution
    """
    # Group by month
    temp = dataframe[[column, 'churn', 'id']].set_index(column).groupby([pd.Grouper(freq='M'), 'churn']).count().unstack(level=1)
    # Plot 
    ax = temp.plot(kind='bar', stacked=True, figsize=(18,10), rot=0)
    # Change x-axis labels to months 
    ax.set_xticklabels(map(lambda x: line_format(x), temp.index))
    # Change xlabel size 
    plt.xticks(fontsize=fontsize_)
    # Rename y-axis
    plt.ylabel('Number of companies')
    # Rename legend 
    plt.legend(['Retention', 'Churn'], loc='upper right')
    plt.show()

def line_format(label):
    """
    Convert time label to the format of pandas line plot
    """
    month = label.month_name()[:1]
    if label.month_name() == 'January':
        month += f'\n{label.year}'
    return month

# %%
plot_dates(date_features, 'date_activ', fontsize_=8)

# %%
plot_dates(date_features, 'date_end')

# %%
plot_dates(date_features, 'date_modif_prod', fontsize_=8)

# %%
plot_dates(date_features, 'date_renewal')

# %% [markdown]
# * Looking at the visualizations above, showing the number of companies with specific date values, it is hard to infer anything. Furthermore, a lot of the values have similar distributions of customers that have churned and those that have not. Due to these reasons, new features may be created from this data at a later stage.

# %% [markdown]
# ### 9. Other columns

# %%
others = client_df[['id', 'nb_prod_act', 'num_years_antig', 'origin_up', 'churn']]
products = others.groupby([others["nb_prod_act"],others["churn"]])["id"].count().unstack(level=1)
products_percentage = (products.div(products.sum(axis=1), axis=0)*100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(products_percentage, "Number of products")

# %%
years_antig = others.groupby([others["num_years_antig"],others["churn"]])["id"].count().unstack(level=1)
years_antig_percentage = (years_antig.div(years_antig.sum(axis=1), axis=0)*100)
plot_stacked_bars(years_antig_percentage, "Number years")

# %%
origin = others.groupby([others["origin_up"],others["churn"]])["id"].count().unstack(level=1)
origin_percentage = (origin.div(origin.sum(axis=1), axis=0)*100)
plot_stacked_bars(origin_percentage, "Origin contract/offer")

# %% [markdown]
# * From the visualization above, there seem to be significant differences in churning rates between the campaigns customers first subscribed to. Also, again there are a lot of missing values present in the column.
#
# * For now, values 'MISSING' in 'channel_sales' and 'origin_up' columns will be treated as a single value for which the code is not known. Performance can be later compared with the one of the known channels/codes filled instead of the 'MISSING'.

# %%
plt.figure(figsize=(16,14))
sns.heatmap(client_df.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * Looking at the correlation figure above, it can be seen that there are some features that are extremely correlated, such as 'imp_cons' and 'forecast_cons_year' or 'cons_last_month' and 'cons_12m'. One of the features in such pairs is likely to be discarded in order to avoid multicollinearity. Furthermore, there are no signficant correlations between 'churn' and any of the features.

# %% [markdown]
# ### EDA For Price Dataset

# %%
for i in price_df.describe():
    plt.clf()
    plt.hist(x=i, data=price_df)
    plt.title(i)
    plt.show()

# %% [markdown]
# * The visualizations above are showing the distributions of values of numerical columns in 'price_data' dataframe. It can be seen that there are a lot of repeating groups of values that are however dispersed from each other.

# %%
for i in price_df.describe():
    plt.clf()
    sns.boxplot(price_df[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# * Considering the outliers in the numerical features of the 'price_data' dataframe, it can be seen that only two of them ('price_off_peak_var' and 'price_off_peak_fix') have outliers.
#
# * Going through the numerical features, a lot of them seemed to have outliers. However, they could be assumed as true outliers as there is quite a few of them for each feature. Therefore, they should be taken into account, rather than left out from the dataset.

# %%
plt.figure(figsize=(16,14))
sns.heatmap(price_df.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * Same as above can be seen in this heatmap figure. Some features are highly correlated and will be considered again after defining price sensitivity.

# %% [markdown]
# ### Hypothesis Testing
# Since we have investigated the information, now is the ideal time to explore whether cost responsiveness has some effect on stir. First we want to characterize precisely exact thing is cost responsiveness.
#
# Since we have the utilization information for every one of the organizations for the extended period of 2015, we will make new highlights to quantify "price sensitivity" utilizing the normal of the year, the most recent a half year and the most recent 3 months.

# %%
# Create mean average data

mean_year = price_df.groupby(['id']).mean().reset_index()
mean_6m = price_df[price_df['price_date'] > '2015-06-01'].groupby(['id']).mean().reset_index()
mean_3m = price_df[price_df['price_date'] > '2015-10-01'].groupby(['id']).mean().reset_index()

# %%
# Comnbine into single dataframe

mean_year = mean_year.rename(index=str, columns={"price_off_peak_var": "mean_year_price_off_peak_var", 
                                                 "price_peak_var": "mean_year_price_peak_var", 
                                                 "price_mid_peak_var": "mean_year_price_mid_peak_var", 
                                                 "price_off_peak_fix": "mean_year_price_off_peak_fix", 
                                                 "price_peak_fix": "mean_year_price_peak_fix", 
                                                 "price_mid_peak_fix": "mean_year_price_mid_peak_fix"})

# %%
mean_year["mean_year_price_off_peak"] = mean_year["mean_year_price_off_peak_var"] + mean_year["mean_year_price_off_peak_fix"]
mean_year["mean_year_price_peak"] = mean_year["mean_year_price_peak_var"] + mean_year["mean_year_price_peak_fix"]
mean_year["mean_year_price_mid_peak"] = mean_year["mean_year_price_mid_peak_var"] + mean_year["mean_year_price_mid_peak_fix"]

# %%
mean_6m = mean_6m.rename(index=str, columns={"price_off_peak_var": "mean_6m_price_off_peak_var", 
                                             "price_peak_var": "mean_6m_price_peak_var", 
                                             "price_mid_peak_var": "mean_6m_price_mid_peak_var", 
                                             "price_off_peak_fix": "mean_6m_price_off_peak_fix", 
                                             "price_peak_fix": "mean_6m_price_peak_fix", 
                                             "price_mid_peak_fix": "mean_6m_price_mid_peak_fix"})

# %%
mean_6m["mean_6m_price_off_peak"] = mean_6m["mean_6m_price_off_peak_var"] + mean_6m["mean_6m_price_off_peak_fix"]
mean_6m["mean_6m_price_peak"] = mean_6m["mean_6m_price_peak_var"] + mean_6m["mean_6m_price_peak_fix"]
mean_6m["mean_6m_price_mid_peak"] = mean_6m["mean_6m_price_mid_peak_var"] + mean_6m["mean_6m_price_mid_peak_fix"]

# %%
mean_3m = mean_3m.rename(index=str, columns={"price_off_peak_var": "mean_3m_price_off_peak_var", 
                                             "price_peak_var": "mean_3m_price_peak_var", 
                                             "price_mid_peak_var": "mean_3m_price_mid_peak_var", 
                                             "price_off_peak_fix": "mean_3m_price_off_peak_fix", 
                                             "price_peak_fix": "mean_3m_price_peak_fix", 
                                             "price_mid_peak_fix": "mean_3m_price_mid_peak_fix"})

# %%
mean_3m["mean_3m_price_off_peak"] = mean_3m["mean_3m_price_off_peak_var"] + mean_3m["mean_3m_price_off_peak_fix"]
mean_3m["mean_3m_price_peak"] = mean_3m["mean_3m_price_peak_var"] + mean_3m["mean_3m_price_peak_fix"]
mean_3m["mean_3m_price_mid_peak"] = mean_3m["mean_3m_price_mid_peak_var"] + mean_3m["mean_3m_price_mid_peak_fix"]

# %%
# Merge into 1 dataframe

price_features = pd.merge(mean_year, mean_6m, on='id')
price_features = pd.merge(price_features, mean_3m, on='id')

# %%
price_features.head()
# Out:
#                                  id  mean_year_price_off_peak_var  \
# 0  0002203ffbb812588b632b9e628cc38d                      0.124338
# 1  0004351ebdd665e6ee664792efc4fd13                      0.146426
# 2  0010bcc39e42b3c2131ed2ce55246e3c                      0.181558
# 3  0010ee3855fdea87602a5b7aba8e42de                      0.118757
# 4  00114d74e963e47177db89bc70108537                      0.147926
#
#    mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 0                  0.103794                      0.073160
# 1                  0.000000                      0.000000
# 2                  0.000000                      0.000000
# 3                  0.098292                      0.069032
# 4                  0.000000                      0.000000
#
#    mean_year_price_off_peak_fix  mean_year_price_peak_fix  \
# 0                     40.701732                 24.421038
# 1                     44.385450                  0.000000
# ...

# %%
price_features.tail()
# Out:
#                                      id  mean_year_price_off_peak_var  \
# 16090  ffef185810e44254c3a4c6395e6b4d8a                      0.138863
# 16091  fffac626da707b1b5ab11e8431a4d0a2                      0.147137
# 16092  fffc0cacd305dd51f316424bbb08d1bd                      0.153879
# 16093  fffe4f5646aa39c7f97f95ae2679ce64                      0.123858
# 16094  ffff7fa066f1fb305ae285bb03bf325a                      0.125360
#
#        mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 16090                  0.115125                      0.080780
# 16091                  0.000000                      0.000000
# 16092                  0.129497                      0.094842
# 16093                  0.103499                      0.073735
# 16094                  0.104895                      0.075635
#
#        mean_year_price_off_peak_fix  mean_year_price_peak_fix  \
# 16090                     40.896427                 24.637456
# ...

# %%
price_features.sample(10)
# Out:
#                                      id  mean_year_price_off_peak_var  \
# 7569   783a6fdbe3c1659808f74bff65d77c9b                      0.125366
# 1844   1c84a6b0d199d24c52733e076e1d5ea3                      0.147261
# 9991   9f8441c798c38f0492d1fbe33cf6ccea                      0.124450
# 3568   374fbd8682af36e185bf72f2d4f075f4                      0.121854
# 4131   3f9378a87c3826de6d2dbcc0b1ff3387                      0.149931
# 4431   449cd5ef65d539682feb24200012d127                      0.149926
# 4274   420b09e9d84442afc992831afe66d67c                      0.125193
# 4666   48ada52261e7cf58715202705a0451c9                      0.103449
# 13876  dc553f78004f33728e7381612582c4c0                      0.124119
# 7657   79ae17c67bd073f120b166973941f22c                      0.166738
#
#        mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 7569                   0.105204                      0.075611
# 1844                   0.000000                      0.000000
# ...

# %% [markdown]
# * Now lets merge in the churn data and see whether price sensitivity has any correlation with churn

# %%
price_analysis = pd.merge(price_features, client_df[['id', 'churn']], on='id')

# %%
price_analysis.head()
# Out:
#                                  id  mean_year_price_off_peak_var  \
# 0  0002203ffbb812588b632b9e628cc38d                      0.124338
# 1  0004351ebdd665e6ee664792efc4fd13                      0.146426
# 2  0010bcc39e42b3c2131ed2ce55246e3c                      0.181558
# 3  00114d74e963e47177db89bc70108537                      0.147926
# 4  0013f326a839a2f6ad87a1859952d227                      0.126076
#
#    mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 0                  0.103794                      0.073160
# 1                  0.000000                      0.000000
# 2                  0.000000                      0.000000
# 3                  0.000000                      0.000000
# 4                  0.105542                      0.074921
#
#    mean_year_price_off_peak_fix  mean_year_price_peak_fix  \
# 0                     40.701732                 24.421038
# 1                     44.385450                  0.000000
# ...

# %%
price_analysis.tail()
# Out:
#                                      id  mean_year_price_off_peak_var  \
# 14600  ffebf6a979dd0b17a41076df1057e733                      0.122426
# 14601  fffac626da707b1b5ab11e8431a4d0a2                      0.147137
# 14602  fffc0cacd305dd51f316424bbb08d1bd                      0.153879
# 14603  fffe4f5646aa39c7f97f95ae2679ce64                      0.123858
# 14604  ffff7fa066f1fb305ae285bb03bf325a                      0.125360
#
#        mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 14600                  0.102375                      0.072210
# 14601                  0.000000                      0.000000
# 14602                  0.129497                      0.094842
# 14603                  0.103499                      0.073735
# 14604                  0.104895                      0.075635
#
#        mean_year_price_off_peak_fix  mean_year_price_peak_fix  \
# 14600                     40.606699                 24.364017
# ...

# %%
price_analysis.sample(10)
# Out:
#                                      id  mean_year_price_off_peak_var  \
# 11505  c9f9018d6d09f0629ad733fdc2f9653c                      0.127797
# 11644  cc7bb3da645cbea795d499e6a7c10c0a                      0.126065
# 14028  f622066f7b15d957a57c3516f8117bb7                      0.145008
# 4966   56be59ae4fa1d3a21fb911683585dfb1                      0.144521
# 10308  b57cb8e6ea3d48c3602c62064ec69693                      0.125607
# 11440  c8e1670dc6de1c0b0a18845cc369653e                      0.124808
# 5181   5ac4b11b7c152186afb9c36efcb32b81                      0.120213
# 3722   3f51055a9cd53747eff132db40350375                      0.150316
# 14493  fe2cdc6c6244568973c919930709b6e3                      0.172486
# 7506   83eea912f1b72b19c25f1871063e4e03                      0.168140
#
#        mean_year_price_peak_var  mean_year_price_mid_peak_var  \
# 11505                  0.107261                      0.076488
# 11644                  0.105505                      0.074850
# ...

# %% [markdown]
# ### Checking Correlation

# %%
corr = price_analysis.corr()
# Plot correlation
plt.figure(figsize=(20,18))
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values,
            annot = True, cmap='RdYlGn', annot_kws={'size':10})

# Axis ticks size
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.savefig("View of Correlation.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# * Although the association with churn is generally quite modest, the correlation plot reveals a higher degree of correlation with other price sensitivity variables. This suggests that price sensitivity and churn have a shaky linear relationship. This shows that we might need to develop the feature differently if we want price sensivity to be a significant factor in predicting churn.

# %%
merged_data = pd.merge(client_df.drop(columns=['churn']), price_analysis, on='id')

# %%
merged_data.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  \
# 0      2015-11-01   2015-06-23               0.00  ...
# ...

# %%
merged_data.tail()
# Out:
#                                      id                     channel_sales  \
# 14600  18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua
# 14601  d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua
# 14602  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14603  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 14600     32270         47940                0  2012-05-24  2016-05-08
# 14601      7223             0              181  2012-08-27  2016-08-27
# 14602      1844             0              179  2012-02-08  2016-02-07
# 14603       131             0                0  2012-08-30  2016-08-30
# 14604      8730             0                0  2009-12-18  2016-12-17
#
#       date_modif_prod date_renewal  forecast_cons_12m  ...  \
# ...

# %%
merged_data.sample(10)
# Out:
#                                      id                     channel_sales  \
# 13752  240e4b4d55561b441cb3e719b2e54930  foosdfpfkusacimwkcsosbicdxkicaua
# 8388   a4d23022c26690ad1dd432547f3f87e2  foosdfpfkusacimwkcsosbicdxkicaua
# 1200   a11230a1ebebd5bae1d0edccd7c72d41  foosdfpfkusacimwkcsosbicdxkicaua
# 9017   e57978eba75a81d4f8fad02431c7c33c  foosdfpfkusacimwkcsosbicdxkicaua
# 12510  84c86f9addc906a2473df57b476ed468  foosdfpfkusacimwkcsosbicdxkicaua
# 10035  5383ec3c7d1d7338eec2888e01a27c44                           MISSING
# 11261  5c2ad6c5e097ea6c631905f07b02ef06                           MISSING
# 1757   53b7cf609a81636871cadafc31023823  usilxuppasemubllopkaafesmlibmsdf
# 4136   a48640db5d6ec07961649b064dc957fb                           MISSING
# 12993  d5e65976cf86de66a5ec4a2379557607                           MISSING
#
#        cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 13752      5100             0                0  2013-07-09  2016-07-09
# ...

# %% [markdown]
# ### Saving the dataframe to "clean_eda_data.csv" file

# %%
merged_data.to_csv("clean_eda_data.csv")
